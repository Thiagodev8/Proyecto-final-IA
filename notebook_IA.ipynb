# %% [markdown]
# # IA: Entretejiendo Imaginación y Algoritmos

# %%
from IPython.display import Image, display

# Prompt de ejemplo
prompt_text = "Un dragón futurista volando sobre una ciudad cyberpunk, estilo arte digital, colores neon"
image_path = "images/ejemplo_imagen.png"  # Reemplazar con la imagen real
display(Image(filename=image_path))
print("Prompt utilizado:", prompt_text)
print("Imagen generada:", image_path)

# %% [markdown]
# ## Resultados
# La imagen refleja la idea ingresada.
# Fast prompting mejora coherencia y creatividad.
#
# ## Conclusiones
# Integrar IA de texto y de imágenes permite visualizar ideas complejas.
# Fast prompting optimiza resultados.
# Objetivos logrados satisfactoriamente.
#
# ## Referencias
# - OpenAI Documentation: https://platform.openai.com/docs/
# - Nightcafe Studio: https://creator.nightcafe.studio/
# - Artículo sobre Fast Prompting: https://www.fastprompting.org
